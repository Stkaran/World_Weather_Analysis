# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from config import weather_api_key
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 721

# %%
# Perform an API call with the OpenWeatherMap.

# Import the API key.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | kampot
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | vanimo
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 1 | jalu
# Processing Record 12 of Set 1 | zaraza
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | sao miguel do araguaia
# Processing Record 16 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | caravelas
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | tuatapere
# Processing Record 22 of Set 1 | pinega
# Processing Record 23 of Set 1 | norman wells
# Processing Record 24 of Set 1 | bodaybo
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | kenai
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | lumphat
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | padang
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | primorsk
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | namibe
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | zherdevka
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | coihueco
# Processing Record 50 of Set 1 | auki
# Processing Record 1 of Set 2 | maracaju
# Processing Record 2 of Set 2 | san patricio
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | makakilo city
# Processing Record 7 of Set 2 | buala
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | taos
# Processing Record 11 of Set 2 | santa lucia
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | biloela
# Processing Record 15 of Set 2 | coromandel
# Processing Record 16 of Set 2 | ambon
# Processing Record 17 of Set 2 | viedma
# Processing Record 18 of Set 2 | quelimane
# Processing Record 19 of Set 2 | saryozek
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | eureka
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | tateyama
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | kondagaon
# Processing Record 33 of Set 2 | stettler
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | sao joao da barra
# Processing Record 37 of Set 2 | thinadhoo
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | sakaiminato
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | mogadishu
# Processing Record 43 of Set 2 | katha
# City not found. Skipping...
# Processing Record 44 of Set 2 | burnie
# Processing Record 45 of Set 2 | port-cartier
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | prado
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | opuwo
# Processing Record 1 of Set 3 | bousso
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | itarema
# Processing Record 5 of Set 3 | nago
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | nara
# Processing Record 8 of Set 3 | terrace
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | komsomolskiy
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | necochea
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | ust-ordynskiy
# Processing Record 15 of Set 3 | torbay
# Processing Record 16 of Set 3 | karratha
# Processing Record 17 of Set 3 | taybad
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | hualmay
# Processing Record 20 of Set 3 | palmer
# Processing Record 21 of Set 3 | ketchikan
# Processing Record 22 of Set 3 | jilib
# Processing Record 23 of Set 3 | coquimbo
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | jijiang
# Processing Record 26 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 3 | nytva
# Processing Record 28 of Set 3 | flagstaff
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | yakeshi
# Processing Record 33 of Set 3 | lebyazhye
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | stokmarknes
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | bilma
# Processing Record 42 of Set 3 | porangatu
# Processing Record 43 of Set 3 | san carlos de bariloche
# Processing Record 44 of Set 3 | kostek
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | acapulco
# Processing Record 50 of Set 3 | dharmadam
# Processing Record 1 of Set 4 | kahului
# Processing Record 2 of Set 4 | suicheng
# Processing Record 3 of Set 4 | maumere
# Processing Record 4 of Set 4 | lasa
# Processing Record 5 of Set 4 | moron
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | surt
# Processing Record 10 of Set 4 | aklavik
# Processing Record 11 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 4 | moura
# Processing Record 13 of Set 4 | lagoa
# Processing Record 14 of Set 4 | porto
# Processing Record 15 of Set 4 | zhanakorgan
# Processing Record 16 of Set 4 | atar
# Processing Record 17 of Set 4 | arrecife
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | riyadh
# Processing Record 20 of Set 4 | namatanai
# Processing Record 21 of Set 4 | constitucion
# Processing Record 22 of Set 4 | lodja
# Processing Record 23 of Set 4 | pokosnoye
# Processing Record 24 of Set 4 | anchorage
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 4 | paamiut
# Processing Record 28 of Set 4 | fort nelson
# Processing Record 29 of Set 4 | hobart
# Processing Record 30 of Set 4 | kisesa
# Processing Record 31 of Set 4 | kijang
# Processing Record 32 of Set 4 | aljezur
# Processing Record 33 of Set 4 | cururupu
# Processing Record 34 of Set 4 | tilichiki
# Processing Record 35 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | sistranda
# Processing Record 38 of Set 4 | vanavara
# Processing Record 39 of Set 4 | ahipara
# Processing Record 40 of Set 4 | codrington
# Processing Record 41 of Set 4 | wewak
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | kikwit
# Processing Record 44 of Set 4 | muyezerskiy
# Processing Record 45 of Set 4 | barcelona
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | nouadhibou
# Processing Record 48 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 49 of Set 4 | vestmannaeyjar
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | salamanca
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | redlands
# Processing Record 4 of Set 5 | osakarovka
# Processing Record 5 of Set 5 | half moon bay
# Processing Record 6 of Set 5 | nishihara
# Processing Record 7 of Set 5 | kesinga
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | sao miguel
# Processing Record 10 of Set 5 | las lomas
# Processing Record 11 of Set 5 | navirai
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | new norfolk
# Processing Record 14 of Set 5 | fare
# Processing Record 15 of Set 5 | tequisquiapan
# Processing Record 16 of Set 5 | faanui
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | vysokogornyy
# Processing Record 19 of Set 5 | rawson
# Processing Record 20 of Set 5 | armidale
# Processing Record 21 of Set 5 | baruun-urt
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | grand gaube
# Processing Record 24 of Set 5 | chapleau
# Processing Record 25 of Set 5 | carnarvon
# Processing Record 26 of Set 5 | guerrero negro
# Processing Record 27 of Set 5 | urumqi
# Processing Record 28 of Set 5 | oranjemund
# Processing Record 29 of Set 5 | yartsevo
# Processing Record 30 of Set 5 | poltavka
# Processing Record 31 of Set 5 | umm kaddadah
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | hami
# Processing Record 34 of Set 5 | sisimiut
# Processing Record 35 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | cayenne
# Processing Record 37 of Set 5 | guaraniacu
# Processing Record 38 of Set 5 | coihaique
# Processing Record 39 of Set 5 | sandanski
# Processing Record 40 of Set 5 | korla
# Processing Record 41 of Set 5 | west wendover
# Processing Record 42 of Set 5 | sitka
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | grootfontein
# Processing Record 45 of Set 5 | bandar-e anzali
# Processing Record 46 of Set 5 | veraval
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | los palacios
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | puerto ayacucho
# Processing Record 1 of Set 6 | aldan
# Processing Record 2 of Set 6 | paidha
# Processing Record 3 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 6 | deputatskiy
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | awbari
# Processing Record 8 of Set 6 | ulladulla
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | balikpapan
# Processing Record 11 of Set 6 | kirkuk
# Processing Record 12 of Set 6 | puerto cabezas
# Processing Record 13 of Set 6 | port lincoln
# Processing Record 14 of Set 6 | beringovskiy
# Processing Record 15 of Set 6 | hemsedal
# Processing Record 16 of Set 6 | sivaki
# Processing Record 17 of Set 6 | lolodorf
# Processing Record 18 of Set 6 | mahibadhoo
# Processing Record 19 of Set 6 | kailua
# Processing Record 20 of Set 6 | rey bouba
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | oussouye
# Processing Record 23 of Set 6 | san quintin
# Processing Record 24 of Set 6 | bambous virieux
# Processing Record 25 of Set 6 | mount gambier
# Processing Record 26 of Set 6 | baykit
# Processing Record 27 of Set 6 | vila
# Processing Record 28 of Set 6 | alyangula
# Processing Record 29 of Set 6 | sola
# Processing Record 30 of Set 6 | maningrida
# Processing Record 31 of Set 6 | novoagansk
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | suchitlan
# Processing Record 34 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | la carolina
# Processing Record 37 of Set 6 | grand-santi
# Processing Record 38 of Set 6 | rocha
# Processing Record 39 of Set 6 | xining
# Processing Record 40 of Set 6 | parry sound
# Processing Record 41 of Set 6 | hengshui
# Processing Record 42 of Set 6 | nhulunbuy
# Processing Record 43 of Set 6 | chhabra
# Processing Record 44 of Set 6 | azuaga
# Processing Record 45 of Set 6 | adrar
# Processing Record 46 of Set 6 | san felipe
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | nauta
# Processing Record 49 of Set 6 | robertsport
# Processing Record 50 of Set 6 | esso
# Processing Record 1 of Set 7 | dingle
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | college
# Processing Record 4 of Set 7 | dongkan
# Processing Record 5 of Set 7 | san miguel
# Processing Record 6 of Set 7 | awjilah
# Processing Record 7 of Set 7 | williston
# Processing Record 8 of Set 7 | meadow lake
# Processing Record 9 of Set 7 | usinsk
# Processing Record 10 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 7 | tari
# Processing Record 12 of Set 7 | huntsville
# Processing Record 13 of Set 7 | liaozhong
# Processing Record 14 of Set 7 | boa vista
# Processing Record 15 of Set 7 | pontianak
# Processing Record 16 of Set 7 | saint george
# Processing Record 17 of Set 7 | wodonga
# Processing Record 18 of Set 7 | sawtell
# Processing Record 19 of Set 7 | arusha
# Processing Record 20 of Set 7 | lac du bonnet
# Processing Record 21 of Set 7 | san nicolas
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | fernandopolis
# Processing Record 24 of Set 7 | la oroya
# Processing Record 25 of Set 7 | prieska
# Processing Record 26 of Set 7 | balta
# Processing Record 27 of Set 7 | huancavelica
# Processing Record 28 of Set 7 | itoman
# Processing Record 29 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | talnakh
# Processing Record 33 of Set 7 | richards bay
# Processing Record 34 of Set 7 | surgut
# Processing Record 35 of Set 7 | oinoi
# Processing Record 36 of Set 7 | villazon
# Processing Record 37 of Set 7 | nuristan
# Processing Record 38 of Set 7 | havre-saint-pierre
# Processing Record 39 of Set 7 | graaff-reinet
# Processing Record 40 of Set 7 | kindu
# Processing Record 41 of Set 7 | fairbanks
# Processing Record 42 of Set 7 | russell
# Processing Record 43 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 44 of Set 7 | tautira
# Processing Record 45 of Set 7 | sao filipe
# Processing Record 46 of Set 7 | tuktoyaktuk
# Processing Record 47 of Set 7 | marawi
# Processing Record 48 of Set 7 | namasuba
# Processing Record 49 of Set 7 | canmore
# Processing Record 50 of Set 7 | tahe
# Processing Record 1 of Set 8 | labuhan
# Processing Record 2 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 3 of Set 8 | rodrigues alves
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | salalah
# Processing Record 6 of Set 8 | phan thiet
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | shchebetovka
# Processing Record 9 of Set 8 | sao joao de pirabas
# Processing Record 10 of Set 8 | linqiong
# Processing Record 11 of Set 8 | dutlwe
# Processing Record 12 of Set 8 | oum hadjer
# Processing Record 13 of Set 8 | marzuq
# Processing Record 14 of Set 8 | cordoba
# Processing Record 15 of Set 8 | shache
# Processing Record 16 of Set 8 | maldonado
# Processing Record 17 of Set 8 | wukari
# Processing Record 18 of Set 8 | waipawa
# Processing Record 19 of Set 8 | banjar
# Processing Record 20 of Set 8 | taua
# Processing Record 21 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 22 of Set 8 | abeche
# Processing Record 23 of Set 8 | nabire
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | slatina
# Processing Record 26 of Set 8 | morehead
# Processing Record 27 of Set 8 | abha
# Processing Record 28 of Set 8 | krasnoselkup
# Processing Record 29 of Set 8 | susanville
# Processing Record 30 of Set 8 | manacor
# Processing Record 31 of Set 8 | shenjiamen
# Processing Record 32 of Set 8 | varadero
# Processing Record 33 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | wakkanai
# Processing Record 36 of Set 8 | ludvika
# Processing Record 37 of Set 8 | concordia
# Processing Record 38 of Set 8 | tessalit
# Processing Record 39 of Set 8 | gushikawa
# Processing Record 40 of Set 8 | iranshahr
# Processing Record 41 of Set 8 | comodoro rivadavia
# Processing Record 42 of Set 8 | houma
# Processing Record 43 of Set 8 | artyom
# Processing Record 44 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 45 of Set 8 | la ronge
# Processing Record 46 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 8 | luoyang
# Processing Record 48 of Set 8 | nome
# Processing Record 49 of Set 8 | chumikan
# Processing Record 50 of Set 8 | ilulissat
# Processing Record 1 of Set 9 | kathmandu
# Processing Record 2 of Set 9 | iqaluit
# Processing Record 3 of Set 9 | san jose pinula
# Processing Record 4 of Set 9 | beaverlodge
# Processing Record 5 of Set 9 | mareeba
# Processing Record 6 of Set 9 | zhurivka
# Processing Record 7 of Set 9 | canora
# Processing Record 8 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 9 | esil
# Processing Record 10 of Set 9 | bagan
# Processing Record 11 of Set 9 | fort-shevchenko
# Processing Record 12 of Set 9 | maragheh
# Processing Record 13 of Set 9 | batagay-alyta
# Processing Record 14 of Set 9 | bonfim
# Processing Record 15 of Set 9 | acarau
# Processing Record 16 of Set 9 | yomou
# Processing Record 17 of Set 9 | somanda
# Processing Record 18 of Set 9 | sumy
# Processing Record 19 of Set 9 | islamnagar
# Processing Record 20 of Set 9 | arauca
# Processing Record 21 of Set 9 | alakurtti
# Processing Record 22 of Set 9 | lieto
# Processing Record 23 of Set 9 | gidam
# Processing Record 24 of Set 9 | chicama
# Processing Record 25 of Set 9 | port hardy
# Processing Record 26 of Set 9 | visnes
# Processing Record 27 of Set 9 | isangel
# Processing Record 28 of Set 9 | ca mau
# Processing Record 29 of Set 9 | cumberland
# Processing Record 30 of Set 9 | tarrega
# Processing Record 31 of Set 9 | abu samrah
# Processing Record 32 of Set 9 | sioux lookout
# Processing Record 33 of Set 9 | gamba
# Processing Record 34 of Set 9 | placido de castro
# Processing Record 35 of Set 9 | piedade
# Processing Record 36 of Set 9 | yerbogachen
# Processing Record 37 of Set 9 | malinao
# Processing Record 38 of Set 9 | mantua
# Processing Record 39 of Set 9 | takaka
# Processing Record 40 of Set 9 | bilibino
# Processing Record 41 of Set 9 | alta floresta
# Processing Record 42 of Set 9 | corovode
# Processing Record 43 of Set 9 | tooele
# Processing Record 44 of Set 9 | puerto escondido
# Processing Record 45 of Set 9 | qaqortoq
# Processing Record 46 of Set 9 | benjamin constant
# Processing Record 47 of Set 9 | kavieng
# Processing Record 48 of Set 9 | liverpool
# Processing Record 49 of Set 9 | udachnyy
# Processing Record 50 of Set 9 | rehoboth
# Processing Record 1 of Set 10 | charleston
# Processing Record 2 of Set 10 | syava
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | brorup
# Processing Record 5 of Set 10 | bentiu
# Processing Record 6 of Set 10 | pailon
# Processing Record 7 of Set 10 | ayr
# Processing Record 8 of Set 10 | ahuimanu
# Processing Record 9 of Set 10 | vila franca do campo
# Processing Record 10 of Set 10 | dire dawa
# Processing Record 11 of Set 10 | saint anthony
# Processing Record 12 of Set 10 | pangnirtung
# Processing Record 13 of Set 10 | mulege
# Processing Record 14 of Set 10 | kamenka
# Processing Record 15 of Set 10 | arlit
# Processing Record 16 of Set 10 | vardo
# Processing Record 17 of Set 10 | aleksandrov gay
# Processing Record 18 of Set 10 | puerto madryn
# Processing Record 19 of Set 10 | yarada
# Processing Record 20 of Set 10 | alingsas
# Processing Record 21 of Set 10 | muros
# Processing Record 22 of Set 10 | poum
# Processing Record 23 of Set 10 | port-gentil
# Processing Record 24 of Set 10 | amla
# Processing Record 25 of Set 10 | teya
# Processing Record 26 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 10 | nuuk
# Processing Record 28 of Set 10 | belaya gora
# Processing Record 29 of Set 10 | mangan
# Processing Record 30 of Set 10 | fort dodge
# Processing Record 31 of Set 10 | tiznit
# Processing Record 32 of Set 10 | yulara
# Processing Record 33 of Set 10 | lokosovo
# Processing Record 34 of Set 10 | santiago de cao
# Processing Record 35 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 10 | ciudad bolivar
# Processing Record 37 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 38 of Set 10 | cascais
# Processing Record 39 of Set 10 | kawalu
# Processing Record 40 of Set 10 | samarai
# Processing Record 41 of Set 10 | faya
# Processing Record 42 of Set 10 | gat
# Processing Record 43 of Set 10 | tiksi
# Processing Record 44 of Set 10 | kaeo
# Processing Record 45 of Set 10 | roma
# Processing Record 46 of Set 10 | todos santos
# Processing Record 47 of Set 10 | tazmalt
# Processing Record 48 of Set 10 | kota belud
# Processing Record 49 of Set 10 | agirish
# Processing Record 50 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 11 | escada
# Processing Record 2 of Set 11 | yucaipa
# Processing Record 3 of Set 11 | cotonou
# Processing Record 4 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 11 | novoilinsk
# Processing Record 6 of Set 11 | nazare
# Processing Record 7 of Set 11 | kigoma
# Processing Record 8 of Set 11 | darhan
# Processing Record 9 of Set 11 | clyde river
# Processing Record 10 of Set 11 | hohhot
# Processing Record 11 of Set 11 | horn lake
# Processing Record 12 of Set 11 | araouane
# Processing Record 13 of Set 11 | chongoyape
# Processing Record 14 of Set 11 | sulina
# Processing Record 15 of Set 11 | ust-nera
# Processing Record 16 of Set 11 | san joaquin
# Processing Record 17 of Set 11 | nelson bay
# Processing Record 18 of Set 11 | te anau
# Processing Record 19 of Set 11 | byron bay
# Processing Record 20 of Set 11 | zhigansk
# Processing Record 21 of Set 11 | huaicheng
# Processing Record 22 of Set 11 | ankazoabo
# Processing Record 23 of Set 11 | felanitx
# Processing Record 24 of Set 11 | razdolinsk
# Processing Record 25 of Set 11 | pringsewu
# Processing Record 26 of Set 11 | kokopo
# Processing Record 27 of Set 11 | ayan
# Processing Record 28 of Set 11 | lucapa
# Processing Record 29 of Set 11 | lavumisa
# Processing Record 30 of Set 11 | chhoti sadri
# Processing Record 31 of Set 11 | vao
# Processing Record 32 of Set 11 | gorgan
# Processing Record 33 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 11 | andros town
# Processing Record 35 of Set 11 | ario
# City not found. Skipping...
# Processing Record 36 of Set 11 | broome
# Processing Record 37 of Set 11 | perico
# Processing Record 38 of Set 11 | ishigaki
# Processing Record 39 of Set 11 | cap malheureux
# Processing Record 40 of Set 11 | sarakhs
# Processing Record 41 of Set 11 | coahuayana
# Processing Record 42 of Set 11 | kurchum
# Processing Record 43 of Set 11 | dubti
# Processing Record 44 of Set 11 | gladstone
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | pemba
# Processing Record 47 of Set 11 | morant bay
# Processing Record 48 of Set 11 | san jose
# Processing Record 49 of Set 11 | akyab
# Processing Record 50 of Set 11 | haicheng
# Processing Record 1 of Set 12 | ryazhsk
# Processing Record 2 of Set 12 | vila velha
# Processing Record 3 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 12 | mikkeli
# Processing Record 5 of Set 12 | seevetal
# Processing Record 6 of Set 12 | berlevag
# Processing Record 7 of Set 12 | selcuk
# Processing Record 8 of Set 12 | avera
# Processing Record 9 of Set 12 | honiara
# Processing Record 10 of Set 12 | usoke
# Processing Record 11 of Set 12 | manokwari
# Processing Record 12 of Set 12 | henties bay
# Processing Record 13 of Set 12 | siocon
# Processing Record 14 of Set 12 | belogorsk
# Processing Record 15 of Set 12 | burkburnett
# Processing Record 16 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | iracoubo
# Processing Record 18 of Set 12 | farafangana
# Processing Record 19 of Set 12 | basco
# Processing Record 20 of Set 12 | pocone
# Processing Record 21 of Set 12 | ponta delgada
# Processing Record 22 of Set 12 | port blair
# Processing Record 23 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 12 | alunitdag
# City not found. Skipping...
# Processing Record 25 of Set 12 | kangalassy
# Processing Record 26 of Set 12 | dhidhdhoo
# Processing Record 27 of Set 12 | lakatoro
# Processing Record 28 of Set 12 | linden
# Processing Record 29 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 12 | polyarnyy
# Processing Record 31 of Set 12 | flin flon
# Processing Record 32 of Set 12 | bonthe
# Processing Record 33 of Set 12 | sochi
# Processing Record 34 of Set 12 | manjacaze
# Processing Record 35 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 12 | hobyo
# Processing Record 37 of Set 12 | sulangan
# Processing Record 38 of Set 12 | san-pedro
# Processing Record 39 of Set 12 | kyaukse
# Processing Record 40 of Set 12 | srandakan
# Processing Record 41 of Set 12 | piacabucu
# Processing Record 42 of Set 12 | sestri levante
# Processing Record 43 of Set 12 | antalaha
# Processing Record 44 of Set 12 | montague
# Processing Record 45 of Set 12 | huambo
# Processing Record 46 of Set 12 | astana
# Processing Record 47 of Set 12 | aykhal
# Processing Record 48 of Set 12 | pangoa
# Processing Record 49 of Set 12 | bad munstereifel
# Processing Record 50 of Set 12 | dwarka
# Processing Record 1 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 13 | mizan teferi
# Processing Record 3 of Set 13 | pemberton
# Processing Record 4 of Set 13 | taoudenni
# Processing Record 5 of Set 13 | chopda
# Processing Record 6 of Set 13 | tabou
# Processing Record 7 of Set 13 | roald
# Processing Record 8 of Set 13 | seydi
# Processing Record 9 of Set 13 | greensboro
# Processing Record 10 of Set 13 | katangli
# Processing Record 11 of Set 13 | uong bi
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | flinders
# Processing Record 14 of Set 13 | dudinka
# Processing Record 15 of Set 13 | mandeville
# Processing Record 16 of Set 13 | odienne
# Processing Record 17 of Set 13 | maun
# Processing Record 18 of Set 13 | mega
# Processing Record 19 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 21 of Set 13 | fukuma
# Processing Record 22 of Set 13 | odweyne
# Processing Record 23 of Set 13 | muramatsu
# Processing Record 24 of Set 13 | amapa
# Processing Record 25 of Set 13 | kultuk
# Processing Record 26 of Set 13 | khor
# Processing Record 27 of Set 13 | naze
# Processing Record 28 of Set 13 | ulaangom
# Processing Record 29 of Set 13 | mandiana
# Processing Record 30 of Set 13 | helena
# Processing Record 31 of Set 13 | kushmurun
# Processing Record 32 of Set 13 | dunedin
# Processing Record 33 of Set 13 | puro
# Processing Record 34 of Set 13 | vilhena
# Processing Record 35 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 13 | maceio
# Processing Record 37 of Set 13 | vulcan
# Processing Record 38 of Set 13 | la rioja
# Processing Record 39 of Set 13 | mandalgovi
# Processing Record 40 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 41 of Set 13 | sainte-rose
# Processing Record 42 of Set 13 | santiago tuxtla
# Processing Record 43 of Set 13 | kaifeng
# Processing Record 44 of Set 13 | iguape
# Processing Record 45 of Set 13 | ipixuna
# Processing Record 46 of Set 13 | saint-joseph
# Processing Record 47 of Set 13 | stolin
# Processing Record 48 of Set 13 | simbahan
# Processing Record 49 of Set 13 | jardim
# Processing Record 50 of Set 13 | denpasar
# Processing Record 1 of Set 14 | smithers
# Processing Record 2 of Set 14 | dong hoi
# Processing Record 3 of Set 14 | yeniseysk
# Processing Record 4 of Set 14 | paita
# Processing Record 5 of Set 14 | juneau
# Processing Record 6 of Set 14 | aksarka
# Processing Record 7 of Set 14 | praia da vitoria
# Processing Record 8 of Set 14 | gimli
# Processing Record 9 of Set 14 | staicele
# Processing Record 10 of Set 14 | antofagasta
# Processing Record 11 of Set 14 | ilmenau
# Processing Record 12 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 14 | tiarei
# Processing Record 14 of Set 14 | houston
# Processing Record 15 of Set 14 | hovd
# Processing Record 16 of Set 14 | los llanos de aridane
# Processing Record 17 of Set 14 | muzhi
# Processing Record 18 of Set 14 | yamada
# Processing Record 19 of Set 14 | san cristobal
# Processing Record 20 of Set 14 | orlik
# Processing Record 21 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 14 | nouakchott
# Processing Record 23 of Set 14 | soyo
# Processing Record 24 of Set 14 | bow island
# Processing Record 25 of Set 14 | katsuura
# Processing Record 26 of Set 14 | rincon
# Processing Record 27 of Set 14 | pacific grove
# Processing Record 28 of Set 14 | effingham
# Processing Record 29 of Set 14 | moba
# Processing Record 30 of Set 14 | karasburg
# Processing Record 31 of Set 14 | atka
# City not found. Skipping...
# Processing Record 32 of Set 14 | aden
# Processing Record 33 of Set 14 | cocobeach
# Processing Record 34 of Set 14 | eyl
# Processing Record 35 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 14 | aksarayskiy
# Processing Record 37 of Set 14 | kamaishi
# Processing Record 38 of Set 14 | kysyl-syr
# Processing Record 39 of Set 14 | salinopolis
# Processing Record 40 of Set 14 | sao jose da coroa grande
# Processing Record 41 of Set 14 | huarmey
# Processing Record 42 of Set 14 | angoche
# Processing Record 43 of Set 14 | batsfjord
# Processing Record 44 of Set 14 | owando
# Processing Record 45 of Set 14 | glenwood springs
# Processing Record 46 of Set 14 | cholet
# Processing Record 47 of Set 14 | cedar rapids
# Processing Record 48 of Set 14 | sangar
# Processing Record 49 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 15 | batemans bay
# Processing Record 2 of Set 15 | robore
# Processing Record 3 of Set 15 | dryden
# Processing Record 4 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 5 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 6 of Set 15 | katy
# Processing Record 7 of Set 15 | beian
# Processing Record 8 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 9 of Set 15 | aktash
# Processing Record 10 of Set 15 | dobrusevo
# Processing Record 11 of Set 15 | sibolga
# Processing Record 12 of Set 15 | parkes
# Processing Record 13 of Set 15 | terrace bay
# Processing Record 14 of Set 15 | camacha
# Processing Record 15 of Set 15 | sivas
# Processing Record 16 of Set 15 | chernyshevskiy
# Processing Record 17 of Set 15 | margate
# Processing Record 18 of Set 15 | shintomi
# Processing Record 19 of Set 15 | candelaria
# Processing Record 20 of Set 15 | naryan-mar
# Processing Record 21 of Set 15 | kununurra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Ribeira Grande      PT  38.5167  -28.7000     71.55        88
# 1            Kampot      KH  10.6167  104.1833     80.65        90
# 2           Rikitea      PF -23.1203 -134.9692     74.26        78
# 3       East London      ZA -33.0153   27.9116     63.63        87
# 4            Vanimo      PG  -2.6741  141.3028     77.76        88
# ..              ...     ...      ...       ...       ...       ...
# 649         Margate      GB  51.3813    1.3862     52.70        72
# 650        Shintomi      JP  32.0785  131.4723     72.72        67
# 651      Candelaria      PH  13.9311  121.4233     78.39        86
# 652      Naryan-Mar      RU  67.6713   53.0870     46.27        79
# 653       Kununurra      AU -15.7667  128.7333     84.18        65
#
#      Cloudiness  Wind Speed Current Description
# 0            61       11.74       broken clouds
# 1           100        6.44     overcast clouds
# 2            99       15.95          light rain
# 3            63       12.12       broken clouds
# 4           100        4.70          light rain
# ..          ...         ...                 ...
# 649          27        7.25    scattered clouds
# 650           0        2.35           clear sky
# 651         100        1.97     overcast clouds
# 652         100       17.63     overcast clouds
# 653          53        4.61       broken clouds
#
# [654 rows x 9 columns]

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
weather_database_file = "WeatherPy_Database.csv"
city_data_df.to_csv(weather_database_file, index_label="City_ID")
